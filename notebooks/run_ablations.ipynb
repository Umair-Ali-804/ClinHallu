# %% [markdown]
# # Ablations B-F
#
# Safe to interrupt. If the session drops, re-run the cells below and the
# completed variants are skipped while the one that was in flight resumes
# from its own checkpoint.

# %%
# %cd /content/drive/MyDrive/clinhallu

# %% [markdown]
# ## What is already done?

# %%
# !clinhallu status

# %% [markdown]
# ## Run all five
#
# Re-run this cell as many times as it takes. Each variant is recorded the
# moment it finishes.

# %%
# !clinhallu ablate --variants B C D E F --seed 13

# %% [markdown]
# ## If one variant fails outright
#
# `--continue-on-error` keeps going through the remaining variants instead of
# stopping at the first failure.

# %%
# !clinhallu ablate --variants B C D E F --seed 13 --continue-on-error

# %% [markdown]
# ## Start over deliberately
#
# Only use this if you want to discard finished variants.

# %%
# !clinhallu ablate --variants B C D E F --seed 13 --no-resume
