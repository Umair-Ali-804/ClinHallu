# %% [markdown]
# # Run one condition (C1-C5)
#
# Re-run the training cell after any interruption; it continues from its last
# checkpoint, including mid-epoch.

# %%
# %cd /content/drive/MyDrive/clinhallu
CONDITION = 'c5'
SEED = 13

# %% [markdown]
# ## What is already done?

# %%
# !clinhallu status

# %% [markdown]
# ## Validate and train

# %%
# !clinhallu validate --config configs/conditions/{CONDITION}.yaml --seed {SEED}
# !clinhallu condition {CONDITION} --seed {SEED}

# %% [markdown]
# ## Re-run only the evaluation stage
#
# Useful when training is finished but you changed something downstream.

# %%
# !clinhallu condition {CONDITION} --seed {SEED} --force-stage evaluate
